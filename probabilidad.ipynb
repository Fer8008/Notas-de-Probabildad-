# %% [markdown]
# <a href="https://colab.research.google.com/github/Fer8008/Notas-de-Probabildad-/blob/main/probabilidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experimneto

# %% [markdown]
# ##Experimento determinista

# %% [markdown]
# ***Un experimento determinista es aquel que siempre tiene el mismo resultado cuando se repite bajo las mismas condiciones***

# %% [markdown]
# ##Area de un circulo

# %%
import sympy

def area(radio):
    return sympy.pi * (radio ** 2)

# %%
area(10)
# Out:
# 100*pi

# %%
def area_numerico(radio):
    return 3.1416 * (radio ** 2)

# %%
area(10)
# Out:
# 100*pi

# %% [markdown]
# # Experimento aleatorio

# %% [markdown]
# ##Lanzamiento de moneda

# %%
import random

moneda_lados = ["aguila", "sol"]

def lanzar_moneda():
    return random.choice(moneda_lados)

lanzar_moneda()
# Out:
# 'aguila'

# %% [markdown]
# ##Experimento aleatorio de dados

# %%
import random

dado_lados = [1, 2, 3, 4, 5, 6 ]

def lanzar_dado():
    return random.choice(dado_lados)

lanzar_dado()
# Out:
# 2

# %%
import random

dado_lados = [1, 2, 3, 4, 5, 6 ]

def lanzar_dado():
    return random.choice(dado_lados)

lanzar_dado()
# Out:
# 4

# %%
import random

dado_lados = [1, 2, 3, 4, 5, 6, 8, 7 ]

def lanzar_dado():
    return random.choice(dado_lados)

lanzar_dado()
# Out:
# 1
